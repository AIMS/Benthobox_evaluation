", "Euphyllidae", "Faviidae encrusting", "Faviidae encrusting, massive & sub-massive", "Fundiidae free-living", "Goniopora & Alveopora", "Green Macroalgae", "Hydnophora branching & Paraclavarina", "Hydnophora other", "Isopora encrusting", "Isopora sub-massive", "Merulina & Scaphophyllia", "Millepora", "Montipora encrusting", "Montipora encrusting, massive & sub-massive", "Montipora foliose", "Mussidae", "Oculinidae", "Other organisms", "Pectiniidae", "Pocillopora damicornis", "Pocillopora other", "Porites branching", "Porites encrusting & sub-massive", "Porites massive", "Porites rus", "Red Macroalgae", "Seriatopora", "Siderastreidae", "Soft coral Alcyoniidae", "Soft coral Briareidae & Rhytisma", "Soft coral Neptheidae", "Soft coral Other", "Soft coral Xeniidae", "Sponges & Ascidians", "Stylophora", "Turf algae", "Zoanthids", "non-Acropora coral ", "non-Acropora coral branching & foliose", "non-Acropora coral encrusting", "other Macroalgae"], "y": [7.680423666910154, 2.07113717491076, 2.2348777348777347, 4.034832246039143, 0.47058823529411764, 0.5, 0.5333333333333333, 2.6333876980428705, 5.551463963963964, 0.7, 0.6666666666666666, 0.5, 0.76001001001001, 0.5, 1.7595526561043804, 1.8416534181240065, 0.6071428571428571, 0.5416666666 ...

# %%
## Bring up a reference from previous experiments
basedir='/Users/uqmgonz1/Dropbox/projects/BenthoBox_evaluation/data/experiments/image_rescale/'
predfiles2=['pred_originalKER.csv']
obs2='obs_originalKER.csv'
results2=mae.MAEplot(basedir, predfiles2,obs2, doplot=False)

# %%
results=results.append(results2, ignore_index=True)

##plot combined results
import plotly.plotly as py
import plotly.offline as pyo
import plotly.tools as tls
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
import plotly.graph_objs as go


data=[]
for i in list(set(results['Experiment'])):
    df=results.loc[results['Experiment'] == i]
    trace=go.Bar(
        x=df['label'],
        y=df['mean'],
        name=str(i),
        error_y=dict(
                type='data',
                symmetric=False,
                array=df['cimax'],
                arrayminus=df['cilow']))
    data.append(trace)

layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
pyo.iplot(fig, filename='error-bar-bar')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="24a5ab5c-8642-461f-a083-00221dc0d208" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("24a5ab5c-8642-461f-a083-00221dc0d208", [{"error_y": {"array": [1.8338203067932781, 0.7332659762566305, 0.3815357413488254, 0.9393056849953396, 0.1969696969696969, 0.0, 0.1923076923076923, 0.6012368300503894, 1.0264639639639652, 0.20454545454545459, 0.44444444444444453, 0.0, 0.13793103448275867, 0.0, 0.39411764705882346, 0.4352941176470586, 0.1071428571428572, 0.12, 0.16591591591591592, 0.1428571428571429, 0.10526315789473684, 0.1799924924924925, 0.18367346938775508, 0.05263157894736842, 0.11643835616438358, 0.5405405405405403, 0.768041237113402, 0.7403846153846154, 0.0957446808510638, 0.07499999999999996, 0.11224489795918369, 0.14, 0.0980392156862745, 0.1298472385428907, 0.1785714285714285, 0.2860909690177982, 0.15625, 0.20833